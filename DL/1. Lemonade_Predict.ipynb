# %% [markdown]
# # Deep Learning Code - Understand

# %%
# Library 불러오기

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# **1. 과거의 데이터를 준비하기**

# %%
# 데이터를 준비합니다.
path = 'https://raw.githubusercontent.com/blackdew/ml-tensorflow/master/data/csv/lemonade.csv'
lemonade = pd.read_csv(path)

lemonade.columns

independent = lemonade[['온도']]
dependent = lemonade[['판매량']]

print(independent.shape, dependent.shape)
# Out:
# (6, 1) (6, 1)

# %% [markdown]
# **2. 모델의 구조 만들기**

# %%
X = tf.keras.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.Model(X, Y)
model.compile(loss='mse')

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 1)]               0
#
#  dense_1 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **3. 데이터로 모델 학습하기**

# %%
history = model.fit(independent, dependent, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 218ms/step - loss: 2765.0515
# Epoch 2/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2757.2209
# Epoch 3/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2751.5515
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2746.8098
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2742.6062
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2738.7568
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2735.1619
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2731.7578
# Epoch 9/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2728.5022
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2725.3652
# Epoch 11/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2722.3254
# Epoch 12/1000
# ...

# %% [markdown]
# **4. 모델 이용**

# %%
model.predict([[15]])
# Out:
# 1/1 [==============================] - 0s 79ms/step
# array([[11.106273]], dtype=float32)

# %%
lemonade.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
model.get_weights()
# Out:
# [array([[0.6734951]], dtype=float32), array([1.003846], dtype=float32)]

# %% [markdown]
# $$ Sales = 1.9874924 * temperature + 0.294783 $$

# %%
# loss 시각화하기
loss = history.history['loss']

plt.plot(loss, label='legend')
plt.show()

# %% [markdown]
# #### MSE
#  <div style="text-align:center;">
#     <img src='https://github.com/Ha-coding-user/aivle_study/blob/main/DL/image/Undeerstand%20Code1.png?raw=true'>
#  </div>
